# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import torch
torch.cuda.set_device(1)

x=torch.Tensor(5,3)
print(x.cuda())
# Out:
# tensor([[ 3.9236e-44,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00, -5.7419e-22,  3.0887e-41],
#         [ 2.3822e-44,  0.0000e+00,  2.3822e-44],
#         [ 0.0000e+00,  1.4013e-45,  0.0000e+00],
#         [-5.7419e-22,  3.0887e-41,  6.3058e-44]], device='cuda:1')

# %%
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import random
from scipy.misc import toimage
import matplotlib.gridspec as gridspec
from matplotlib.ticker import MaxNLocator
import PIL
import sys
import seaborn as sns
import sklearn.metrics
import pickle

# %%
print(torch.__version__)
# Out:
# 1.1.0a0+828a6a3

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %% [markdown]
# # Exploring the CIFAR-10 dataset

# %%
metaDataPath = '../dataset/cifar-10-batches-py/batches.meta'
metaData = unpickle(metaDataPath)
label_names_bin = 'label_names'.encode('utf-8')
labelNames = metaData[label_names_bin]
labelNames = [x.decode() for x in labelNames]
labelNames
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %% [markdown]
# ## Control Flags

# %%
data_aug = True

# %% [markdown]
# ## Easier way to load data using torch

# %%
data_aug_transforms = []

if data_aug == True:

    data_aug_transforms = [
        transforms.RandomCrop((32,32), padding=4),
#         transforms.RandomHorizontalFlip(),
#         transforms.RandomRotation(15),
#         transforms.RandomAffine(degrees=0, translate=(.3,.7)),
#         transforms.ColorJitter(
#                 brightness=float(0.1*np.random.rand(1)),
#                 contrast=float(0.1*np.random.rand(1)),
#                 saturation=float(0.1*np.random.rand(1)),
#                 hue=float(0.1*np.random.rand(1))),
#         
#         transforms.Resize((224,224)),
        transforms.ColorJitter(hue=.25, saturation=.25),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(20, resample=PIL.Image.BILINEAR),
        transforms.RandomGrayscale(p=0.1)
                    ]

# %%
norm_transform = transforms.Compose(data_aug_transforms+[transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                     ])
test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                     ])

# %%
# cifar_dataset = torchvision.datasets.CIFAR10(root='dataset/',
#                                            train=True,
#                                            transform=norm_transform,
#                                            download=False)

# test_dataset = torchvision.datasets.CIFAR10(root='dataset/',
#                                           train=False,
#                                           transform=test_transform)

# %%
cifar_dataset = torchvision.datasets.CIFAR10(root='../dataset/',
                                           train=True,
                                           transform=norm_transform,
                                           download=False)

test_dataset = torchvision.datasets.CIFAR10(root='../dataset/',
                                          train=False,
                                          transform=test_transform)

# %%
cifar_dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Split: train
#     Root Location: ../dataset/
#     Transforms (if any): Compose(
#                              RandomCrop(size=(32, 32), padding=4)
#                              ColorJitter(brightness=0, contrast=0, saturation=0.25, hue=0.25)
#                              RandomHorizontalFlip(p=0.5)
#                              RandomRotation(degrees=(-20, 20), resample=2, expand=False)
#                              RandomGrayscale(p=0.1)
#                              ToTensor()
#                              Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#                          )
#     Target Transforms (if any): None

# %%
test_dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Split: test
#     Root Location: ../dataset/
#     Transforms (if any): Compose(
#                              ToTensor()
#                              Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#                          )
#     Target Transforms (if any): None

# %%
exampleNumber = 1
img = cifar_dataset[exampleNumber][0]
num = cifar_dataset[exampleNumber][1]
# name = cifar_dataset.classes[num]
name = labelNames[num]

print('Image in the train dataset has shape:',img.size())
print('Label corresponding to image is:',num)
print('Label ',num,'is:',name)

img = np.rollaxis(np.array(img),0,3)

plt.figure(figsize=(2,2))
plt.title('Label Name:'+ name+ '\n Label #:'+str(num))
plt.imshow(toimage(img))
plt.show()
# Out:
# Image in the train dataset has shape: torch.Size([3, 32, 32])
# Label corresponding to image is: 9
# Label  9 is: truck

# %%
b,g,r = cv2.split(img)
r = toimage(r)
g=toimage(g)
b = toimage(b)

fig, axs = plt.subplots(2,2)

cax_00 = axs[0,0].imshow(toimage(img))
axs[0,0].set_title('Original')
axs[0,0].set_xticks([])
axs[0,0].set_yticks([])

cax_01 = axs[0,1].imshow(r, cmap='Reds')
axs[0,1].set_title('Red Channel')
axs[0,1].set_xticks([])
axs[0,1].set_yticks([])
fig.colorbar(cax_01, ax=axs[0,1])

cax_10 = axs[1,0].imshow(g, cmap='Greens')
axs[1,0].set_title('Green Channel')
axs[1,0].set_xticks([])
axs[1,0].set_yticks([])
fig.colorbar(cax_10, ax=axs[1,0])

cax_11 = axs[1,1].imshow(b, cmap='Blues')
axs[1,1].set_title('Blue Channel')
axs[1,1].set_xticks([])
axs[1,1].set_yticks([])
fig.colorbar(cax_11, ax=axs[1,1])

plt.suptitle('Different colour cahnnels of the '+ name+ ' image:', color ='gray')
plt.show()

# %%
r = np.array(r).flatten()
g = np.array(g).flatten()
b = np.array(b).flatten()

# %%
# Plot histograms
fig, axs = plt.subplots(3, sharex=True, sharey=True, figsize=(6,6))
fig.text(0.5, 0.04, 'Pixel color values', ha='center')
fig.text(0.04, 0.5, 'Count', va='center', rotation='vertical')

axs[0].hist(r, bins=10, color='red', ec='black')
axs[0].set_title('Red Channel Histogram')
axs[1].hist(g.ravel(), bins=10, color='green', ec='black')
axs[1].set_title('Green Channel Histogram')
axs[2].hist(b.ravel(), bins=10, ec='black')
axs[2].set_title('Blue Channel Histogram')

plt.show()

# %% [markdown]
# ## Visualizing all class members

# %%
def classMembers(dataset, numMembersOfEachClass = 2):
    
    imagesOfEachClass = {}
    
    for label in range(10):
        imagesOfEachClass[label] = []
        for i in range(numMembersOfEachClass):
            rand = random.randint(0, len(dataset))
            while dataset[rand][1] != label:
                rand = random.randint(0, len(dataset))
            img = dataset[rand][0]
            imagesOfEachClass[label].append(img)
    return imagesOfEachClass

def visualizeClassMembers(imagesOfEachClass, datasetLabelNames):
    rows = len(imagesOfEachClass)
    cols = len(imagesOfEachClass[1])
    
    fig, axs = plt.subplots(figsize=(32.0, 32.0), nrows=rows, ncols=cols)
#     gs1 = gridspec.GridSpec(4, 4)
#     gs1.update(wspace=0.005, hspace=0.005) # set the spacing between axes.
    
    for r in range(rows):
        for c in range(cols):
            img = imagesOfEachClass[r][c-1]
            img = np.rollaxis(np.array(img),0,3)
            col = axs[r,c]
            col.imshow(toimage(img))
            col.set_title(datasetLabelNames[r])
            
    plt.subplots_adjust(wspace=0, hspace=0)
    fig.tight_layout()
    plt.show()
    
    return None

# %%
imagesOfEachClass = classMembers(cifar_dataset)
# visualizeClassMembers(imagesOfEachClass, cifar_dataset.classes)
visualizeClassMembers(imagesOfEachClass, labelNames)

# %% [markdown]
# ## Visualize Augmented data

# %%
def show_dataset(dataset, n=6):
    img = np.vstack((np.hstack((np.asarray(np.rollaxis(np.array(dataset[i][0]),0,3)) for _ in range(n))) 
                     for i in range(n)))
    fig, axs = plt.subplots(1, figsize=(32,32))
    axs.imshow(toimage(img))
    plt.axis('off')

show_dataset(cifar_dataset)

# %% [markdown]
# ## Visualizing distribution of different classes

# %%
def getLabels(dataset):
    labels = []
    for i in range(len(dataset)):
        labels.append(dataset[i][1])
    return labels

trainLabels = getLabels(cifar_dataset)
testLabels = getLabels(test_dataset)

# %%
# trainLabels = cifar_dataset.targets
# testLabels = test_dataset.targets

uniqueValuesTrain, occurCountTrain = np.unique(trainLabels, return_counts=True)
uniqueValuesTest, occurCountTest = np.unique(testLabels, return_counts=True)

ind = np.arange(len(occurCountTrain))  # the x locations for the groups
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(16,16))
rects1 = ax.bar(ind - width/2, occurCountTrain, width, 
                label='Train')
rects2 = ax.bar(ind + width/2, occurCountTest, width,
                label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Frequency')
ax.set_xlabel('Classes in CIFAR10')
ax.set_title('Class distribution in CIFAR10')
ax.set_xticks(ind)
ax.set_xticklabels(labelNames)
ax.legend()
fig.show()

# %%
def weights_init(m):
    if type(m) == nn.Linear:
        m.weight.data.normal_(0.0, 1e-3)
        m.bias.data.fill_(0.)

def update_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device: %s'%device)
# Out:
# Using device: cuda

# %%
input_size = 32 * 32 * 3
listOfHiddenSizes = [[50], [50, 40], [50, 40, 30], [50, 40, 30, 25], [50, 40, 30, 25, 20]]
num_classes = 10
num_epochs = 50
batch_size = 200
learning_rate = 1e-3
learning_rate_decay = 0.95
reg=0.001
num_training= 49000
num_validation =1000
train = True

# %%
mask = list(range(num_training))
train_dataset = torch.utils.data.Subset(cifar_dataset, mask)
mask = list(range(num_training, num_training + num_validation))
val_dataset = torch.utils.data.Subset(cifar_dataset, mask)

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=batch_size,
                                           shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)

# %%
class MultiLayerPerceptron(nn.Module):
    def __init__(self, input_size, hidden_layers, num_classes):
        super(MultiLayerPerceptron, self).__init__()
    
        layers = []
        
        layers.append(nn.Linear(input_size, hidden_layers[0]))
        layers.append( nn.ReLU() )

        for i in range(1, len(hidden_layers)):
            
            layers.append( nn.Linear(hidden_layers[i-1], hidden_layers[i]) )
            layers.append( nn.ReLU() )
        
        layers.append( nn.Linear(hidden_layers[-1], num_classes) )
        
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        
        for i in range(len(self.layers)):
            x = self.layers[i](x)

        out = x
        return out

# %%
def run_training(model, train_loader, learning_rate, learning_rate_decay, num_epochs, early_stopping=True):
    
    model.apply(weights_init)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

    # Train the model
    lr = learning_rate
    total_step = len(train_loader)
    
    valAcc = []
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            # Move tensors to the configured device
            images = images.to(device)
            labels = labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            outputs = model(images.reshape(batch_size,-1))
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            if (i+1) % 100 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                       .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

        # Code to update the lr
        lr *= learning_rate_decay
        update_lr(optimizer, lr)
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                predicted = model(images.reshape(batch_size,-1))
                _ , predicted = torch.max(predicted, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            
            acc = 100*correct/total
            valAcc.append(acc)
            print('Validataion accuracy is: {} %'.format(acc))
            
            if early_stopping:
                if acc >= np.amax(valAcc):
                    torch.save(model.state_dict(), 'DNN_models/ES/model'+str(epoch+1)+'.ckpt')
                    
    best_id = np.argmax(valAcc)
#     model = ConvNet(input_size, hidden_size, num_classes, norm_layer=norm_layer).to(device)
    model.load_state_dict(torch.load('DNN_models/ES/model'+str(best_id+1)+'.ckpt'))
    
    return valAcc

# %%
def run_testing(model, test_loader):

    # Test the model
    # In test phase, we don't need to compute gradients (for memory efficiency)
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images.reshape(batch_size,-1))
            _ , predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        testAcc = 100 * correct / total
        print('Accuracy of the network on the {} test images: {} %'.format(total, testAcc))
        
        return testAcc

# %%
def trainMultipleHiddenSizes(listOfHiddenSizes, visualizeES = False, visualizeLayers = False, train = False):
    
    bestESModelValAcc = []
    allValAccs = []
    for hid in range(len(listOfHiddenSizes)):
        print('#################################################')
        print('Training Model ', hid)

        hidden_size = listOfHiddenSizes[hid]

        model = MultiLayerPerceptron(input_size, hidden_size, num_classes).to(device)
        print(model)

        if train:
            valAcc = run_training(model, train_loader, learning_rate, learning_rate_decay, num_epochs)
            allValAccs.append(valAcc)
            bestESModelValAcc.append(np.max(np.array(valAcc)))
            
            # Save the model checkpoint
            torch.save(model.state_dict(), 'DNN_models/DNN_model'+str(hid)+'.ckpt')
    
    bestModel_ID = np.argmax(np.array(bestESModelValAcc))
    
    if visualizeES:
        valAcc = allValAccs[bestModel_ID]
        epochs = [int(i) for i in range(1, num_epochs+1)]
        ax = plt.figure().gca()
        ax.xaxis.set_major_locator(MaxNLocator(integer=True))
        plt.plot(epochs,valAcc)
        plt.xlabel('number of epochs')
        plt.ylabel('validation accuracy')
        plt.show()
        
    if visualizeLayers:
        x=[i for i in range(1, len(listOfHiddenSizes)+1)]
        ax = plt.figure().gca()
        ax.xaxis.set_major_locator(MaxNLocator(integer=True))
        plt.bar(x, bestESModelValAcc)
        plt.xlabel('Layers')
        plt.ylabel('Validation Accuracy')
        plt.show()
        
    return bestModel_ID

# %%
def testMultipleParamVals(paramVals, train=False, visualizeTestAcc = False):
    
    testAcc = []
    for hid in range(len(paramVals)):
        hidden_size = paramVals[hid]

        model = MultiLayerPerceptron(input_size, hidden_size, num_classes).to(device)
        if not train:
            # Run the test code once you have your by setting train flag to false
            # and loading the best model

            best_model = torch.load('DNN_models/DNN_model'+str(hid)+'.ckpt')
            model.load_state_dict(best_model)

            testAcc.append(run_testing(model, test_loader))
    
    if visualizeTestAcc:
        x=[i for i in range(1, len(paramVals)+1)]
        ax = plt.figure().gca()
        ax.xaxis.set_major_locator(MaxNLocator(integer=True))
        plt.bar(x, testAcc)
        plt.xlabel('Models')
        plt.ylabel('Test accuracy')
        plt.show()

# %%
listOfHiddenSizes = [[50], [50, 40], [50, 40, 30], [50, 40, 30, 25], [50, 40, 30, 25, 20]]
train = True
bestModel_ID = trainMultipleHiddenSizes(listOfHiddenSizes, visualizeES = True, visualizeLayers = True, train= train)
# Out:
# #################################################
# Training Model  0
# MultiLayerPerceptron(
#   (layers): Sequential(
#     (0): Linear(in_features=3072, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=10, bias=True)
#   )
# )
# Epoch [1/50], Step [100/245], Loss: 2.0545
# Epoch [1/50], Step [200/245], Loss: 1.9779
# Validataion accuracy is: 29.7 %
# Epoch [2/50], Step [100/245], Loss: 1.9543
# Epoch [2/50], Step [200/245], Loss: 1.8570
# Validataion accuracy is: 32.7 %
# Epoch [3/50], Step [100/245], Loss: 1.8833
# Epoch [3/50], Step [200/245], Loss: 1.8656
# Validataion accuracy is: 35.8 %
# Epoch [4/50], Step [100/245], Loss: 1.7972
# Epoch [4/50], Step [200/245], Loss: 1.7086
# Validataion accuracy is: 34.0 %
# Epoch [5/50], Step [100/245], Loss: 1.8248
# Epoch [5/50], Step [200/245], Loss: 1.7759
# Validataion accuracy is: 36.3 %
# Epoch [6/50], Step [100/245], Loss: 1.7678
# Epoch [6/50], Step [200/245], Loss: 1.8561
# Validataion accuracy is: 36.8 %
# Epoch [7/50], Step [100/245], Loss: 1.7688
# Epoch [7/50], Step [200/245], Loss: 1.7108
# Validataion accuracy is: 35.4 %
# Epoch [8/50], Step [100/245], Loss: 1.6917
# Epoch [8/50], Step [200/245], Loss: 1.8721
# Validataion accuracy is: 37.0 %
# Epoch [9/50], Step [100/245], Loss: 1.6566
# Epoch [9/50], Step [200/245], Loss: 1.7099
# Validataion accuracy is: 37.5 %
# Epoch [10/50], Step [100/245], Loss: 1.8565
# Epoch [10/50], Step [200/245], Loss: 1.7537
# Validataion accuracy is: 36.5 %
# Epoch [11/50], Step [100/245], Loss: 1.7786
# Epoch [11/50], Step [200/245], Loss: 1.6330
# Validataion accuracy is: 37.3 %
# Epoch [12/50], Step [100/245], Loss: 1.8296
# Epoch [12/50], Step [200/245], Loss: 1.5718
# Validataion accuracy is: 39.0 %
# Epoch [13/50], Step [100/245], Loss: 1.6768
# Epoch [13/50], Step [200/245], Loss: 1.6629
# Validataion accuracy is: 38.0 %
# Epoch [14/50], Step [100/245], Loss: 1.7462
# Epoch [14/50], Step [200/245], Loss: 1.7790
# Validataion accuracy is: 39.7 %
# Epoch [15/50], Step [100/245], Loss: 1.7729
# Epoch [15/50], Step [200/245], Loss: 1.7218
# Validataion accuracy is: 40.2 %
# Epoch [16/50], Step [100/245], Loss: 1.6581
# Epoch [16/50], Step [200/245], Loss: 1.6235
# Validataion accuracy is: 39.6 %
# Epoch [17/50], Step [100/245], Loss: 1.7577
# Epoch [17/50], Step [200/245], Loss: 1.7403
# Validataion accuracy is: 41.8 %
# Epoch [18/50], Step [100/245], Loss: 1.7069
# Epoch [18/50], Step [200/245], Loss: 1.7376
# Validataion accuracy is: 38.5 %
# Epoch [19/50], Step [100/245], Loss: 1.7666
# Epoch [19/50], Step [200/245], Loss: 1.6622
# Validataion accuracy is: 41.9 %
# Epoch [20/50], Step [100/245], Loss: 1.6410
# Epoch [20/50], Step [200/245], Loss: 1.7538
# Validataion accuracy is: 41.9 %
# Epoch [21/50], Step [100/245], Loss: 1.6581
# Epoch [21/50], Step [200/245], Loss: 1.8061
# Validataion accuracy is: 40.4 %
# Epoch [22/50], Step [100/245], Loss: 1.7380
# Epoch [22/50], Step [200/245], Loss: 1.7364
# Validataion accuracy is: 40.7 %
# Epoch [23/50], Step [100/245], Loss: 1.7309
# Epoch [23/50], Step [200/245], Loss: 1.6418
# Validataion accuracy is: 41.0 %
# Epoch [24/50], Step [100/245], Loss: 1.6846
# Epoch [24/50], Step [200/245], Loss: 1.5835
# Validataion accuracy is: 42.8 %
# Epoch [25/50], Step [100/245], Loss: 1.7180
# Epoch [25/50], Step [200/245], Loss: 1.6650
# Validataion accuracy is: 41.4 %
# Epoch [26/50], Step [100/245], Loss: 1.7375
# Epoch [26/50], Step [200/245], Loss: 1.7139
# Validataion accuracy is: 42.2 %
# Epoch [27/50], Step [100/245], Loss: 1.7322
# Epoch [27/50], Step [200/245], Loss: 1.6232
# Validataion accuracy is: 42.2 %
# Epoch [28/50], Step [100/245], Loss: 1.6956
# Epoch [28/50], Step [200/245], Loss: 1.7974
# Validataion accuracy is: 43.5 %
# Epoch [29/50], Step [100/245], Loss: 1.7241
# Epoch [29/50], Step [200/245], Loss: 1.6905
# Validataion accuracy is: 40.3 %
# Epoch [30/50], Step [100/245], Loss: 1.7212
# Epoch [30/50], Step [200/245], Loss: 1.6537
# Validataion accuracy is: 42.9 %
# Epoch [31/50], Step [100/245], Loss: 1.6532
# Epoch [31/50], Step [200/245], Loss: 1.7590
# Validataion accuracy is: 41.6 %
# Epoch [32/50], Step [100/245], Loss: 1.7392
# Epoch [32/50], Step [200/245], Loss: 1.7949
# Validataion accuracy is: 40.5 %
# Epoch [33/50], Step [100/245], Loss: 1.6818
# Epoch [33/50], Step [200/245], Loss: 1.7830
# Validataion accuracy is: 41.8 %
# Epoch [34/50], Step [100/245], Loss: 1.7493
# Epoch [34/50], Step [200/245], Loss: 1.6381
# Validataion accuracy is: 40.9 %
# Epoch [35/50], Step [100/245], Loss: 1.7368
# Epoch [35/50], Step [200/245], Loss: 1.6353
# Validataion accuracy is: 39.6 %
# Epoch [36/50], Step [100/245], Loss: 1.6757
# Epoch [36/50], Step [200/245], Loss: 1.6107
# Validataion accuracy is: 43.1 %
# Epoch [37/50], Step [100/245], Loss: 1.6380
# Epoch [37/50], Step [200/245], Loss: 1.6392
# Validataion accuracy is: 42.9 %
# Epoch [38/50], Step [100/245], Loss: 1.6395
# Epoch [38/50], Step [200/245], Loss: 1.7350
# Validataion accuracy is: 41.8 %
# Epoch [39/50], Step [100/245], Loss: 1.7364
# Epoch [39/50], Step [200/245], Loss: 1.7348
# Validataion accuracy is: 41.1 %
# Epoch [40/50], Step [100/245], Loss: 1.7055
# Epoch [40/50], Step [200/245], Loss: 1.6261
# Validataion accuracy is: 41.9 %
# Epoch [41/50], Step [100/245], Loss: 1.5893
# Epoch [41/50], Step [200/245], Loss: 1.6322
# Validataion accuracy is: 41.3 %
# Epoch [42/50], Step [100/245], Loss: 1.6840
# Epoch [42/50], Step [200/245], Loss: 1.7274
# Validataion accuracy is: 42.8 %
# Epoch [43/50], Step [100/245], Loss: 1.6098
# Epoch [43/50], Step [200/245], Loss: 1.6980
# Validataion accuracy is: 41.3 %
# Epoch [44/50], Step [100/245], Loss: 1.6698
# Epoch [44/50], Step [200/245], Loss: 1.7383
# Validataion accuracy is: 40.2 %
# Epoch [45/50], Step [100/245], Loss: 1.6520
# Epoch [45/50], Step [200/245], Loss: 1.6846
# Validataion accuracy is: 40.6 %
# Epoch [46/50], Step [100/245], Loss: 1.6178
# Epoch [46/50], Step [200/245], Loss: 1.6107
# Validataion accuracy is: 41.8 %
# Epoch [47/50], Step [100/245], Loss: 1.6126
# Epoch [47/50], Step [200/245], Loss: 1.6813
# Validataion accuracy is: 42.4 %
# Epoch [48/50], Step [100/245], Loss: 1.7100
# Epoch [48/50], Step [200/245], Loss: 1.6528
# Validataion accuracy is: 41.9 %
# Epoch [49/50], Step [100/245], Loss: 1.7354
# Epoch [49/50], Step [200/245], Loss: 1.6398
# Validataion accuracy is: 43.0 %
# Epoch [50/50], Step [100/245], Loss: 1.5661
# Epoch [50/50], Step [200/245], Loss: 1.7289
# Validataion accuracy is: 42.9 %
# #################################################
# Training Model  1
# MultiLayerPerceptron(
#   (layers): Sequential(
#     (0): Linear(in_features=3072, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=40, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=40, out_features=10, bias=True)
#   )
# )
# Epoch [1/50], Step [100/245], Loss: 2.1569
# Epoch [1/50], Step [200/245], Loss: 2.0983
# Validataion accuracy is: 22.8 %
# Epoch [2/50], Step [100/245], Loss: 2.0263
# Epoch [2/50], Step [200/245], Loss: 1.9733
# Validataion accuracy is: 26.9 %
# Epoch [3/50], Step [100/245], Loss: 1.9127
# Epoch [3/50], Step [200/245], Loss: 1.9896
# Validataion accuracy is: 31.4 %
# Epoch [4/50], Step [100/245], Loss: 1.9144
# Epoch [4/50], Step [200/245], Loss: 1.9156
# Validataion accuracy is: 35.4 %
# Epoch [5/50], Step [100/245], Loss: 1.8645
# Epoch [5/50], Step [200/245], Loss: 1.7652
# Validataion accuracy is: 34.4 %
# Epoch [6/50], Step [100/245], Loss: 1.8125
# Epoch [6/50], Step [200/245], Loss: 1.8227
# Validataion accuracy is: 37.1 %
# Epoch [7/50], Step [100/245], Loss: 1.7177
# Epoch [7/50], Step [200/245], Loss: 1.7862
# Validataion accuracy is: 37.5 %
# Epoch [8/50], Step [100/245], Loss: 1.7887
# Epoch [8/50], Step [200/245], Loss: 1.7848
# Validataion accuracy is: 35.1 %
# Epoch [9/50], Step [100/245], Loss: 1.8077
# Epoch [9/50], Step [200/245], Loss: 1.6486
# Validataion accuracy is: 36.1 %
# Epoch [10/50], Step [100/245], Loss: 1.6980
# Epoch [10/50], Step [200/245], Loss: 1.8809
# Validataion accuracy is: 37.6 %
# Epoch [11/50], Step [100/245], Loss: 1.7008
# Epoch [11/50], Step [200/245], Loss: 1.8029
# Validataion accuracy is: 38.1 %
# Epoch [12/50], Step [100/245], Loss: 1.7518
# Epoch [12/50], Step [200/245], Loss: 1.7067
# Validataion accuracy is: 40.1 %
# Epoch [13/50], Step [100/245], Loss: 1.6707
# Epoch [13/50], Step [200/245], Loss: 1.7319
# Validataion accuracy is: 40.2 %
# Epoch [14/50], Step [100/245], Loss: 1.7376
# Epoch [14/50], Step [200/245], Loss: 1.6777
# Validataion accuracy is: 39.7 %
# Epoch [15/50], Step [100/245], Loss: 1.6462
# Epoch [15/50], Step [200/245], Loss: 1.5765
# Validataion accuracy is: 40.7 %
# Epoch [16/50], Step [100/245], Loss: 1.6976
# Epoch [16/50], Step [200/245], Loss: 1.6861
# Validataion accuracy is: 41.8 %
# Epoch [17/50], Step [100/245], Loss: 1.5358
# Epoch [17/50], Step [200/245], Loss: 1.6997
# Validataion accuracy is: 39.0 %
# Epoch [18/50], Step [100/245], Loss: 1.6963
# Epoch [18/50], Step [200/245], Loss: 1.7956
# Validataion accuracy is: 41.1 %
# Epoch [19/50], Step [100/245], Loss: 1.7116
# Epoch [19/50], Step [200/245], Loss: 1.6435
# Validataion accuracy is: 41.2 %
# Epoch [20/50], Step [100/245], Loss: 1.7658
# Epoch [20/50], Step [200/245], Loss: 1.5946
# Validataion accuracy is: 40.0 %
# Epoch [21/50], Step [100/245], Loss: 1.6505
# Epoch [21/50], Step [200/245], Loss: 1.6457
# Validataion accuracy is: 40.6 %
# Epoch [22/50], Step [100/245], Loss: 1.5902
# Epoch [22/50], Step [200/245], Loss: 1.6025
# Validataion accuracy is: 41.9 %
# Epoch [23/50], Step [100/245], Loss: 1.5803
# Epoch [23/50], Step [200/245], Loss: 1.5969
# Validataion accuracy is: 40.7 %
# Epoch [24/50], Step [100/245], Loss: 1.7343
# Epoch [24/50], Step [200/245], Loss: 1.6987
# Validataion accuracy is: 40.7 %
# Epoch [25/50], Step [100/245], Loss: 1.7334
# Epoch [25/50], Step [200/245], Loss: 1.6489
# Validataion accuracy is: 40.8 %
# Epoch [26/50], Step [100/245], Loss: 1.7088
# Epoch [26/50], Step [200/245], Loss: 1.6615
# Validataion accuracy is: 43.0 %
# Epoch [27/50], Step [100/245], Loss: 1.5652
# Epoch [27/50], Step [200/245], Loss: 1.6966
# Validataion accuracy is: 42.5 %
# Epoch [28/50], Step [100/245], Loss: 1.6285
# Epoch [28/50], Step [200/245], Loss: 1.6829
# Validataion accuracy is: 42.4 %
# Epoch [29/50], Step [100/245], Loss: 1.6406
# Epoch [29/50], Step [200/245], Loss: 1.7013
# Validataion accuracy is: 42.6 %
# Epoch [30/50], Step [100/245], Loss: 1.6245
# Epoch [30/50], Step [200/245], Loss: 1.6848
# Validataion accuracy is: 41.7 %
# Epoch [31/50], Step [100/245], Loss: 1.7078
# Epoch [31/50], Step [200/245], Loss: 1.6478
# Validataion accuracy is: 42.0 %
# Epoch [32/50], Step [100/245], Loss: 1.6428
# Epoch [32/50], Step [200/245], Loss: 1.6704
# Validataion accuracy is: 43.4 %
# Epoch [33/50], Step [100/245], Loss: 1.8093
# Epoch [33/50], Step [200/245], Loss: 1.6492
# Validataion accuracy is: 41.3 %
# Epoch [34/50], Step [100/245], Loss: 1.7251
# Epoch [34/50], Step [200/245], Loss: 1.5902
# Validataion accuracy is: 40.4 %
# Epoch [35/50], Step [100/245], Loss: 1.6833
# Epoch [35/50], Step [200/245], Loss: 1.5694
# Validataion accuracy is: 41.7 %
# Epoch [36/50], Step [100/245], Loss: 1.5756
# Epoch [36/50], Step [200/245], Loss: 1.6273
# Validataion accuracy is: 42.6 %
# Epoch [37/50], Step [100/245], Loss: 1.6433
# Epoch [37/50], Step [200/245], Loss: 1.6892
# Validataion accuracy is: 42.5 %
# Epoch [38/50], Step [100/245], Loss: 1.5163
# Epoch [38/50], Step [200/245], Loss: 1.6422
# Validataion accuracy is: 40.2 %
# Epoch [39/50], Step [100/245], Loss: 1.6907
# Epoch [39/50], Step [200/245], Loss: 1.6455
# Validataion accuracy is: 41.1 %
# Epoch [40/50], Step [100/245], Loss: 1.6751
# Epoch [40/50], Step [200/245], Loss: 1.5636
# Validataion accuracy is: 40.9 %
# Epoch [41/50], Step [100/245], Loss: 1.5952
# Epoch [41/50], Step [200/245], Loss: 1.6484
# Validataion accuracy is: 43.7 %
# Epoch [42/50], Step [100/245], Loss: 1.6054
# Epoch [42/50], Step [200/245], Loss: 1.5973
# Validataion accuracy is: 45.1 %
# Epoch [43/50], Step [100/245], Loss: 1.5639
# Epoch [43/50], Step [200/245], Loss: 1.7080
# Validataion accuracy is: 44.5 %
# Epoch [44/50], Step [100/245], Loss: 1.6665
# Epoch [44/50], Step [200/245], Loss: 1.5020
# Validataion accuracy is: 42.4 %
# Epoch [45/50], Step [100/245], Loss: 1.5838
# Epoch [45/50], Step [200/245], Loss: 1.5206
# Validataion accuracy is: 42.0 %
# Epoch [46/50], Step [100/245], Loss: 1.6678
# Epoch [46/50], Step [200/245], Loss: 1.6395
# Validataion accuracy is: 42.8 %
# Epoch [47/50], Step [100/245], Loss: 1.6796
# Epoch [47/50], Step [200/245], Loss: 1.5675
# Validataion accuracy is: 43.3 %
# Epoch [48/50], Step [100/245], Loss: 1.5283
# Epoch [48/50], Step [200/245], Loss: 1.6912
# Validataion accuracy is: 43.8 %
# Epoch [49/50], Step [100/245], Loss: 1.6359
# Epoch [49/50], Step [200/245], Loss: 1.6641
# Validataion accuracy is: 42.7 %
# Epoch [50/50], Step [100/245], Loss: 1.5834
# Epoch [50/50], Step [200/245], Loss: 1.6104
# Validataion accuracy is: 42.8 %
# #################################################
# Training Model  2
# MultiLayerPerceptron(
#   (layers): Sequential(
#     (0): Linear(in_features=3072, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=40, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=40, out_features=30, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=30, out_features=10, bias=True)
#   )
# )
# Epoch [1/50], Step [100/245], Loss: 2.3028
# Epoch [1/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [2/50], Step [100/245], Loss: 2.3036
# Epoch [2/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 10.2 %
# Epoch [3/50], Step [100/245], Loss: 2.3024
# Epoch [3/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [4/50], Step [100/245], Loss: 2.3032
# Epoch [4/50], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [5/50], Step [100/245], Loss: 2.3025
# Epoch [5/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [6/50], Step [100/245], Loss: 2.3032
# Epoch [6/50], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.8 %
# Epoch [7/50], Step [100/245], Loss: 2.3018
# Epoch [7/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [8/50], Step [100/245], Loss: 2.3024
# Epoch [8/50], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [9/50], Step [100/245], Loss: 2.3033
# Epoch [9/50], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [10/50], Step [100/245], Loss: 2.3037
# Epoch [10/50], Step [200/245], Loss: 2.3019
# Validataion accuracy is: 7.8 %
# Epoch [11/50], Step [100/245], Loss: 2.3022
# Epoch [11/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [12/50], Step [100/245], Loss: 2.3027
# Epoch [12/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [13/50], Step [100/245], Loss: 2.3031
# Epoch [13/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [14/50], Step [100/245], Loss: 2.3030
# Epoch [14/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [15/50], Step [100/245], Loss: 2.3029
# Epoch [15/50], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 8.7 %
# Epoch [16/50], Step [100/245], Loss: 2.3027
# Epoch [16/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [17/50], Step [100/245], Loss: 2.3031
# Epoch [17/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [18/50], Step [100/245], Loss: 2.3022
# Epoch [18/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [19/50], Step [100/245], Loss: 2.3025
# Epoch [19/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [20/50], Step [100/245], Loss: 2.3027
# Epoch [20/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [21/50], Step [100/245], Loss: 2.3026
# Epoch [21/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 8.7 %
# Epoch [22/50], Step [100/245], Loss: 2.3031
# Epoch [22/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [23/50], Step [100/245], Loss: 2.3024
# Epoch [23/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [24/50], Step [100/245], Loss: 2.3026
# Epoch [24/50], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.8 %
# Epoch [25/50], Step [100/245], Loss: 2.3027
# Epoch [25/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [26/50], Step [100/245], Loss: 2.3024
# Epoch [26/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [27/50], Step [100/245], Loss: 2.3031
# Epoch [27/50], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.8 %
# Epoch [28/50], Step [100/245], Loss: 2.3023
# Epoch [28/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [29/50], Step [100/245], Loss: 2.3027
# Epoch [29/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [30/50], Step [100/245], Loss: 2.3024
# Epoch [30/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [31/50], Step [100/245], Loss: 2.3027
# Epoch [31/50], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [32/50], Step [100/245], Loss: 2.3026
# Epoch [32/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [33/50], Step [100/245], Loss: 2.3025
# Epoch [33/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [34/50], Step [100/245], Loss: 2.3027
# Epoch [34/50], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [35/50], Step [100/245], Loss: 2.3023
# Epoch [35/50], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.8 %
# Epoch [36/50], Step [100/245], Loss: 2.3024
# Epoch [36/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [37/50], Step [100/245], Loss: 2.3028
# Epoch [37/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [38/50], Step [100/245], Loss: 2.3026
# Epoch [38/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [39/50], Step [100/245], Loss: 2.3025
# Epoch [39/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [40/50], Step [100/245], Loss: 2.3025
# Epoch [40/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [41/50], Step [100/245], Loss: 2.3025
# Epoch [41/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [42/50], Step [100/245], Loss: 2.3027
# Epoch [42/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [43/50], Step [100/245], Loss: 2.3026
# Epoch [43/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [44/50], Step [100/245], Loss: 2.3025
# Epoch [44/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [45/50], Step [100/245], Loss: 2.3025
# Epoch [45/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [46/50], Step [100/245], Loss: 2.3022
# Epoch [46/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [47/50], Step [100/245], Loss: 2.3025
# Epoch [47/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [48/50], Step [100/245], Loss: 2.3025
# Epoch [48/50], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.9 %
# Epoch [49/50], Step [100/245], Loss: 2.3026
# Epoch [49/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [50/50], Step [100/245], Loss: 2.3025
# Epoch [50/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# #################################################
# Training Model  3
# MultiLayerPerceptron(
#   (layers): Sequential(
#     (0): Linear(in_features=3072, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=40, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=40, out_features=30, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=30, out_features=25, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=25, out_features=10, bias=True)
#   )
# )
# Epoch [1/50], Step [100/245], Loss: 2.3023
# Epoch [1/50], Step [200/245], Loss: 2.3035
# Validataion accuracy is: 8.7 %
# Epoch [2/50], Step [100/245], Loss: 2.3033
# Epoch [2/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 8.7 %
# Epoch [3/50], Step [100/245], Loss: 2.3030
# Epoch [3/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [4/50], Step [100/245], Loss: 2.3023
# Epoch [4/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [5/50], Step [100/245], Loss: 2.3021
# Epoch [5/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [6/50], Step [100/245], Loss: 2.3029
# Epoch [6/50], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [7/50], Step [100/245], Loss: 2.3027
# Epoch [7/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [8/50], Step [100/245], Loss: 2.3026
# Epoch [8/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [9/50], Step [100/245], Loss: 2.3025
# Epoch [9/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [10/50], Step [100/245], Loss: 2.3028
# Epoch [10/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [11/50], Step [100/245], Loss: 2.3023
# Epoch [11/50], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [12/50], Step [100/245], Loss: 2.3027
# Epoch [12/50], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [13/50], Step [100/245], Loss: 2.3025
# Epoch [13/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [14/50], Step [100/245], Loss: 2.3026
# Epoch [14/50], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.8 %
# Epoch [15/50], Step [100/245], Loss: 2.3027
# Epoch [15/50], Step [200/245], Loss: 2.3034
# Validataion accuracy is: 7.8 %
# Epoch [16/50], Step [100/245], Loss: 2.3022
# Epoch [16/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [17/50], Step [100/245], Loss: 2.3028
# Epoch [17/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [18/50], Step [100/245], Loss: 2.3032
# Epoch [18/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [19/50], Step [100/245], Loss: 2.3023
# Epoch [19/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [20/50], Step [100/245], Loss: 2.3025
# Epoch [20/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [21/50], Step [100/245], Loss: 2.3028
# Epoch [21/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [22/50], Step [100/245], Loss: 2.3026
# Epoch [22/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [23/50], Step [100/245], Loss: 2.3028
# Epoch [23/50], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [24/50], Step [100/245], Loss: 2.3024
# Epoch [24/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [25/50], Step [100/245], Loss: 2.3025
# Epoch [25/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [26/50], Step [100/245], Loss: 2.3022
# Epoch [26/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [27/50], Step [100/245], Loss: 2.3025
# Epoch [27/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [28/50], Step [100/245], Loss: 2.3026
# Epoch [28/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [29/50], Step [100/245], Loss: 2.3022
# Epoch [29/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [30/50], Step [100/245], Loss: 2.3024
# Epoch [30/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [31/50], Step [100/245], Loss: 2.3025
# Epoch [31/50], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.9 %
# Epoch [32/50], Step [100/245], Loss: 2.3022
# Epoch [32/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [33/50], Step [100/245], Loss: 2.3027
# Epoch [33/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [34/50], Step [100/245], Loss: 2.3025
# Epoch [34/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [35/50], Step [100/245], Loss: 2.3026
# Epoch [35/50], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [36/50], Step [100/245], Loss: 2.3030
# Epoch [36/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [37/50], Step [100/245], Loss: 2.3024
# Epoch [37/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [38/50], Step [100/245], Loss: 2.3024
# Epoch [38/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [39/50], Step [100/245], Loss: 2.3025
# Epoch [39/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [40/50], Step [100/245], Loss: 2.3025
# Epoch [40/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [41/50], Step [100/245], Loss: 2.3026
# Epoch [41/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [42/50], Step [100/245], Loss: 2.3028
# Epoch [42/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [43/50], Step [100/245], Loss: 2.3027
# Epoch [43/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [44/50], Step [100/245], Loss: 2.3027
# Epoch [44/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [45/50], Step [100/245], Loss: 2.3026
# Epoch [45/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [46/50], Step [100/245], Loss: 2.3027
# Epoch [46/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [47/50], Step [100/245], Loss: 2.3021
# Epoch [47/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [48/50], Step [100/245], Loss: 2.3024
# Epoch [48/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [49/50], Step [100/245], Loss: 2.3025
# Epoch [49/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [50/50], Step [100/245], Loss: 2.3028
# Epoch [50/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# #################################################
# Training Model  4
# MultiLayerPerceptron(
#   (layers): Sequential(
#     (0): Linear(in_features=3072, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=40, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=40, out_features=30, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=30, out_features=25, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=25, out_features=20, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=20, out_features=10, bias=True)
#   )
# )
# Epoch [1/50], Step [100/245], Loss: 2.3023
# Epoch [1/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 10.7 %
# Epoch [2/50], Step [100/245], Loss: 2.3021
# Epoch [2/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [3/50], Step [100/245], Loss: 2.3020
# Epoch [3/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 11.2 %
# Epoch [4/50], Step [100/245], Loss: 2.3025
# Epoch [4/50], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 8.7 %
# Epoch [5/50], Step [100/245], Loss: 2.3027
# Epoch [5/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 8.7 %
# Epoch [6/50], Step [100/245], Loss: 2.3029
# Epoch [6/50], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.8 %
# Epoch [7/50], Step [100/245], Loss: 2.3029
# Epoch [7/50], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.9 %
# Epoch [8/50], Step [100/245], Loss: 2.3026
# Epoch [8/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [9/50], Step [100/245], Loss: 2.3028
# Epoch [9/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [10/50], Step [100/245], Loss: 2.3031
# Epoch [10/50], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [11/50], Step [100/245], Loss: 2.3026
# Epoch [11/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [12/50], Step [100/245], Loss: 2.3027
# Epoch [12/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [13/50], Step [100/245], Loss: 2.3028
# Epoch [13/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [14/50], Step [100/245], Loss: 2.3025
# Epoch [14/50], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [15/50], Step [100/245], Loss: 2.3025
# Epoch [15/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 8.7 %
# Epoch [16/50], Step [100/245], Loss: 2.3026
# Epoch [16/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [17/50], Step [100/245], Loss: 2.3022
# Epoch [17/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [18/50], Step [100/245], Loss: 2.3026
# Epoch [18/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 8.7 %
# Epoch [19/50], Step [100/245], Loss: 2.3026
# Epoch [19/50], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.9 %
# Epoch [20/50], Step [100/245], Loss: 2.3028
# Epoch [20/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [21/50], Step [100/245], Loss: 2.3024
# Epoch [21/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [22/50], Step [100/245], Loss: 2.3025
# Epoch [22/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [23/50], Step [100/245], Loss: 2.3028
# Epoch [23/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [24/50], Step [100/245], Loss: 2.3027
# Epoch [24/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [25/50], Step [100/245], Loss: 2.3025
# Epoch [25/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [26/50], Step [100/245], Loss: 2.3023
# Epoch [26/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [27/50], Step [100/245], Loss: 2.3031
# Epoch [27/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 8.7 %
# Epoch [28/50], Step [100/245], Loss: 2.3026
# Epoch [28/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [29/50], Step [100/245], Loss: 2.3027
# Epoch [29/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [30/50], Step [100/245], Loss: 2.3027
# Epoch [30/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [31/50], Step [100/245], Loss: 2.3025
# Epoch [31/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [32/50], Step [100/245], Loss: 2.3028
# Epoch [32/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [33/50], Step [100/245], Loss: 2.3023
# Epoch [33/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [34/50], Step [100/245], Loss: 2.3029
# Epoch [34/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [35/50], Step [100/245], Loss: 2.3026
# Epoch [35/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [36/50], Step [100/245], Loss: 2.3022
# Epoch [36/50], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [37/50], Step [100/245], Loss: 2.3027
# Epoch [37/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [38/50], Step [100/245], Loss: 2.3025
# Epoch [38/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [39/50], Step [100/245], Loss: 2.3025
# Epoch [39/50], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [40/50], Step [100/245], Loss: 2.3025
# Epoch [40/50], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [41/50], Step [100/245], Loss: 2.3029
# Epoch [41/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [42/50], Step [100/245], Loss: 2.3029
# Epoch [42/50], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [43/50], Step [100/245], Loss: 2.3026
# Epoch [43/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [44/50], Step [100/245], Loss: 2.3024
# Epoch [44/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [45/50], Step [100/245], Loss: 2.3029
# Epoch [45/50], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [46/50], Step [100/245], Loss: 2.3026
# Epoch [46/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [47/50], Step [100/245], Loss: 2.3025
# Epoch [47/50], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [48/50], Step [100/245], Loss: 2.3026
# Epoch [48/50], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [49/50], Step [100/245], Loss: 2.3025
# Epoch [49/50], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [50/50], Step [100/245], Loss: 2.3026
# Epoch [50/50], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %

# %%
train = False

# %%
testMultipleParamVals(listOfHiddenSizes, train=train, visualizeTestAcc = True)
# Out:
# Accuracy of the network on the 10000 test images: 40.48 %
# Accuracy of the network on the 10000 test images: 42.52 %
# Accuracy of the network on the 10000 test images: 10.0 %
# Accuracy of the network on the 10000 test images: 10.0 %
# Accuracy of the network on the 10000 test images: 10.0 %

# %%
# !pip install seaborn

# %%
def display_classification_results(y_test, y_pred,title="Accuracy Heatmap",show_report=True):
    print("Test accuracy: %.2f%%"%(sklearn.metrics.accuracy_score(y_test, y_pred)*100))
    if show_report:
        print("Classification Report:\n",sklearn.metrics.classification_report(y_test, y_pred))
    plt.rcParams['figure.figsize'] = (10.0, 8.0)
    conf_mat = sklearn.metrics.confusion_matrix(y_test,y_pred)
    print("Confusion Matrix:\n",conf_mat)
    ax = sns.heatmap(conf_mat);
    ax.set(title=title, xlabel="CIFAR10 Classes", ylabel="CIFAR10 Classes")

# %%
pickle.dump( bestModel_ID, open( "DNN_models/bestModelID.p", "wb" ) )
bestModel_ID = pickle.load( open( "DNN_models/bestModelID.p", "rb" ) )

# %%
bestmodel = MultiLayerPerceptron(input_size, listOfHiddenSizes[bestModel_ID], num_classes).to(device)
bestmodel.load_state_dict(torch.load('DNN_models/DNN_model'+str(bestModel_ID)+'.ckpt'))

# %%
def run_testing_labels(model, test_loader):

    # Test the model
    with torch.no_grad():
        correct = 0
        total = 0
        allPredLabels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images.reshape(batch_size,-1))
            _ , predicted = torch.max(outputs, 1)
            allPredLabels.append(predicted)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        testAcc = 100 * correct / total
        print('Accuracy of the network on the {} test images: {} %'.format(total, testAcc))
        
        return testAcc, allPredLabels

# %%
testLabels = getLabels(test_dataset)
_, bestModelPreds = run_testing_labels(bestmodel, test_loader)
# Out:
# Accuracy of the network on the 10000 test images: 42.52 %

# %%
bestModelPreds = [i.tolist() for i in bestModelPreds]
bestModelPreds = [item for sublist in bestModelPreds for item in sublist]
len(bestModelPreds)
# Out:
# 10000

# %%
display_classification_results(testLabels, bestModelPreds, title="Accuracy Heatmap",show_report=True)
# Out:
# Test accuracy: 42.52%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.46      0.51      1000
#            1       0.42      0.66      0.51      1000
#            2       0.39      0.20      0.26      1000
#            3       0.33      0.17      0.22      1000
#            4       0.48      0.13      0.21      1000
#            5       0.32      0.48      0.39      1000
#            6       0.53      0.39      0.45      1000
#            7       0.37      0.64      0.47      1000
#            8       0.55      0.58      0.56      1000
#            9       0.40      0.53      0.46      1000
#
#     accuracy                           0.43     10000
#    macro avg       0.44      0.43      0.41     10000
# weighted avg       0.44      0.43      0.41     10000
#
# Confusion Matrix:
#  [[458  97  34  11   5  21  24  65 161 124]
#  [ 11 660   4  14   3  19   6  30  62 191]
#  [ 96  62 201  66  44 210  61 176  37  47]
#  [ 33  72  51 171  12 311  87 146  40  77]
#  [ 44  49 109  47 133 145  94 308  33  38]
#  [ 21  41  37  90   7 483  58 169  44  50]
#  [  5 101  64  65  53 144 392  94  27  55]
#  [ 30  56  11  35  10 114   7 644  22  71]
#  [ 77 147   5   5   7  23   4  22 583 127]
#  [ 16 281   4  20   2  18  10  67  55 527]]

# %%
def visualizePreds(y_test, y_pred, test_dataset, labelNames, visualizeCorrect=False):
    
    correct = np.array(y_test) == np.array(y_pred)
    pos = []
    posPredLabel = []
    posTrueLabel = []
    
    if visualizeCorrect:
        while len(pos) <= 10:
            i = random.randint(0, len(y_pred))
            if y_test[i] == y_pred[i]:

                
                pos.append(i)
                posPredLabel.append(y_pred[i])
                posTrueLabel.append(y_test[i])

    else:
        while len(pos) <= 10:
            i = random.randint(0, len(y_pred))
            if y_test[i] != y_pred[i]:
                pos.append(i)
                posPredLabel.append(y_pred[i])
                posTrueLabel.append(y_test[i])
                
    
    fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(16,16))

    i = 0
    for row in ax:
        for col in row:
            img = test_dataset[pos[i]][0]
            img = np.rollaxis(np.array(img),0,3)
            col.imshow(toimage(img))
            col.set_title('True Label: '+str(y_test[pos[i]])+' '+labelNames[y_test[pos[i]]]+'\n Pred Label: '+str(y_pred[pos[i]])+' '+labelNames[y_pred[pos[i]]])
            col.set_xticks([])
            col.set_yticks([])
            i += 1
            
    plt.tight_layout()
    plt.show()

# %%
# Visualizing incorrect predictions
visualizePreds(testLabels, bestModelPreds,test_dataset, labelNames)

# %%
# Visualizing correct predictions
visualizePreds(testLabels, bestModelPreds, test_dataset, labelNames, True)
